# %%
import pandas as pd

df = pd.read_json('yelp_academic_dataset_review.json',lines=True)

# %%
df
# Out:
#                       review_id                 user_id  \
# 0        KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA
# 1        BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q
# 2        saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A
# 3        AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ
# 4        Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ
# ...                         ...                     ...
# 6990275  H0RIamZu0B0Ei0P4aeh3sQ  qskILQ3k0I_qcCMI-k6_QQ
# 6990276  shTPgbgdwTHSuU67mGCmZQ  Zo0th2m8Ez4gLSbHftiQvg
# 6990277  YNfNhgZlaaCO5Q_YJR4rEw  mm6E4FbCMwJmb7kPDZ5v2Q
# 6990278  i-I4ZOhoX70Nw5H0FwrQUA  YwAMC-jvZ1fvEUum6QkEkw
# 6990279  RwcKOdEuLRHNJe4M9-qpqg  6JehEvdoCvZPJ_XIxnzIIw
#
#                     business_id  stars  useful  funny  cool  \
# 0        XQfwVwDr-v0ZS3_CbbE5Xw      3       0      0     0
# 1        7ATYjTIgM3jUlt4UM3IypQ      5       1      0     1
# 2        YjUWPpI6HXG530lwP-fb2A      3       0      0     0
# ...

# %%
Positive_stars = df[(df['stars'] == 4) | (df['stars'] == 5)].sample(25000)

# %%
Positive_stars
# Out:
#                       review_id                 user_id  \
# 164284   OHodTGAjtxp5lNkFOHHNDA  CMQ66mdfbGZkeU5K-KVOCw
# 3092574  50jhqUXiH-WWoKXyidmarw  22Zd2AYOwVhMIWvS-jwebA
# 5755540  mw8yzxz0D1GXNKCSUcQUAg  I-13tlo6mFNCmpBTuUYDuw
# 451077   CJ-lc3VlU29XevfIErvZGg  um4H6Mm4xNVEr5coEGAKcg
# 2525842  9QO-sijquoa_2veDIfFmgQ  dgf1AeYczUQbvkjbotWsQQ
# ...                         ...                     ...
# 352583   g2_nDwXQtXGVgyMTD1J9ow  IHmrY1RQzaJeQHX7ES0uLQ
# 2232699  FkqKI1HrHdRGmdgCKNX-Bw  RnjWmBWHMc_gel3oQgrl8g
# 4373280  Z4TRr2WRMUQCgcCNQgx3Fg  73MRrt4TT5PUWkNwoOvhWA
# 6404209  xXhACtWZah_qTITTEXrIDg  A_eCBvgUL8MdaR9tIo741Q
# 865537   0v7S1KgAlnIgtKE9OZLlVQ  bnPpoAsVbULVN8EsUYGGCA
#
#                     business_id  stars  useful  funny  cool  \
# 164284   ut6fi2W2YaipNOqvi7e0jw      5       1      0     1
# 3092574  q-zV08jt6U-q05SMEuQJAQ      5       2      1     2
# 5755540  6Gon-iz1NnzPPbwQhIG60A      5       2      0     0
# ...

# %%
Neutral_stars = df[(df['stars'] == 3)].sample(25000)

# %%
Neutral_stars
# Out:
#                       review_id                 user_id  \
# 6006457  iUBds-pvZwgfVNROo0hxpg  YS3shR8RfHnOu5Xyi_ew4Q
# 935044   fDefotq_3cxVhUclG8XMpg  z67oNAZR_uHG84k3Dntckg
# 4242865  YvnTSPvNo3Y0ojumnHTC6g  ln99M1ahEQNqKtEPFr2lTg
# 4485296  JYCGFYHCX1dRMlq197EeHQ  ao-AH4CKrHlJLdrxYm9reg
# 3719021  Dh7pEqzs5YEitxIj9IZOsA  6_Bg26_Za4X2orcooY3Oxg
# ...                         ...                     ...
# 4828747  eVttt35JUSfCwbGjVjZwGw  1JIkFpJaATdeL_FSqgh0aA
# 3589398  Fk_QEez5A_47XdEAJQeHRA  IFh8kiTHNguv0NiJ0TPxnw
# 3653539  SZIWsNzJJN5imjlsZ7QP2A  KR2nyTod_DM_kTVgoLyGkA
# 1763485  vX4wNOVR2HV6cXgrMkoIaQ  _kcHxYPXRYjU4hk2xtCO0w
# 3618064  aUSDIcsZ19QD3De9wgEYCA  Ari6H4eY-GOWv_sFkpyq7Q
#
#                     business_id  stars  useful  funny  cool  \
# 6006457  6DSwG39rfdeeKz22KiRBbA      3       2      0     0
# 935044   IORvbG2rAIVJ-1d148cCmg      3       6      8     2
# 4242865  06BbJ-yKBlf9uHZSNGsO9Q      3       0      0     0
# ...

# %%
Negative_stars = df[(df['stars'] == 1) | (df['stars'] == 2)].sample(25000)

# %%
Negative_stars
# Out:
#                       review_id                 user_id  \
# 1117359  eFKcDpecmwg0dk9ujc2z9w  DqdnA0rT-CrUfsMCiFfROg
# 4254142  PcVKDyBgu0iONWosoJiC5Q  7VqOMsoA72QpvGMOhR0y0A
# 632427   U6WAQi8wUYcFPqxUa82H9w  t33lxpSWtrwQID8qI9gxfw
# 4003230  EiutUjYu8kFucSo2e9jPjg  34ijTmOavWudcZzjuCmeXQ
# 2442023  EItDrghfN07J8dcrqqVVlA  kjlhPieXBPx7PqX8K4aQ9A
# ...                         ...                     ...
# 3906774  D-EuSAKIEUjQ9RK5fvn4Wg  yfzJiR-UbNVT6_tOd4neYA
# 2143534  2yg4OwdRp2gPh48eUE7r3A  Eur0z9Fa0pRucuY4WPtgEA
# 3088030  ZkPAj2T1MKR00VgOHOJaYg  2on-VIXmdDfX0p8DR55HSg
# 2932459  myka2J-I0UO_qFGUt763bQ  DVHxau2YSLDKzg98xsl-4Q
# 3566017  lqIpmgABmbNoNQJ9tL_3RQ  JQ8FB6RmUnk4Ti2FiHSCJA
#
#                     business_id  stars  useful  funny  cool  \
# 1117359  LmZWlvPJBwj5WG2KHV-v1Q      1       0      1     0
# 4254142  LEyWxCngS9m5hWc9coJD4g      2       1      0     0
# 632427   cXAKeC-EgVChIxhS7fscmw      2       4      0     0
# ...

# %%
df_List = [Positive_stars, Neutral_stars, Negative_stars]
New_df = pd.concat(df_List)

# %%
New_df
# Out:
#                       review_id                 user_id  \
# 164284   OHodTGAjtxp5lNkFOHHNDA  CMQ66mdfbGZkeU5K-KVOCw
# 3092574  50jhqUXiH-WWoKXyidmarw  22Zd2AYOwVhMIWvS-jwebA
# 5755540  mw8yzxz0D1GXNKCSUcQUAg  I-13tlo6mFNCmpBTuUYDuw
# 451077   CJ-lc3VlU29XevfIErvZGg  um4H6Mm4xNVEr5coEGAKcg
# 2525842  9QO-sijquoa_2veDIfFmgQ  dgf1AeYczUQbvkjbotWsQQ
# ...                         ...                     ...
# 3906774  D-EuSAKIEUjQ9RK5fvn4Wg  yfzJiR-UbNVT6_tOd4neYA
# 2143534  2yg4OwdRp2gPh48eUE7r3A  Eur0z9Fa0pRucuY4WPtgEA
# 3088030  ZkPAj2T1MKR00VgOHOJaYg  2on-VIXmdDfX0p8DR55HSg
# 2932459  myka2J-I0UO_qFGUt763bQ  DVHxau2YSLDKzg98xsl-4Q
# 3566017  lqIpmgABmbNoNQJ9tL_3RQ  JQ8FB6RmUnk4Ti2FiHSCJA
#
#                     business_id  stars  useful  funny  cool  \
# 164284   ut6fi2W2YaipNOqvi7e0jw      5       1      0     1
# 3092574  q-zV08jt6U-q05SMEuQJAQ      5       2      1     2
# 5755540  6Gon-iz1NnzPPbwQhIG60A      5       2      0     0
# ...

# %%
shuffled_Df = New_df.sample(frac=1)

# %%
shuffled_Df
# Out:
#                       review_id                 user_id  \
# 2866685  EZhsez9rcRcnz5vzdDprgQ  Jcg0KyxNMTSlOeEfI78LMA
# 4007935  UASULpgxM45JQdbuAk4o2g  6s-g2vFu12OemhiK3FJuOQ
# 6726516  4NuztpkW80grQEdbRJ1HKw  NzmoFvh-YIXSJU8_k6jgdA
# 1457784  LzQkTCQfO3DVXE52TKo6VA  u1LTgEJmd8FZmDxxrgHwGw
# 6891     wf-W_7E6uNJmXiSiMdvPsw  Vwslifegl59fQVOe5BH1gw
# ...                         ...                     ...
# 3955822  UniXnVymUjCW9mKoN_JKQA  _qpZgV3vrYUYvBD5MDW6oQ
# 1200031  0kPJptO5U5vl5gikPrqNMw  -ftREF8vomubEfe8_CdE_w
# 4556263  RZyyNSRNoqd7SRcmM2nl5w  uXA2S9glwAFZ-boRNhkeVQ
# 4326689  DHNUXvNWGtAzMPKzutSJrw  rzRuWYc9-JOCtx2VbcxaZg
# 5643078  -8tcsPMRFHjp0tDWrJPsAg  CAKTUNTsuyCfsSpzjGptcg
#
#                     business_id  stars  useful  funny  cool  \
# 2866685  _9Z3cuZQBOGv_XzSG4ewHA      1       5      1     0
# 4007935  G_VpU7J9do8ZRCLIblDBZA      3       5      1     5
# 6726516  X7yGrz7oDbt8UY5rdmJc_w      5       1      0     0
# ...

# %%
shuffled_Df.loc[shuffled_Df['stars'] == 2]
# Out:
#                       review_id                 user_id  \
# 6022763  -eVCXAsy7CNs7ZIB7SG70A  Z9655SIfsrLQ8C466AcATw
# 4956041  tZAU5Ie9DLxXzLJCgfk9fw  u7T9sTYWb1Ef8kYm0qzMcQ
# 6032674  jd094g2PRytglXygXebuzA  j-1gskpTS7P0nNWq-AtNhA
# 36293    6_3NdzCFqvnMiJfc3UF1Wg  Zj_SwzaCWeiYQUD19GwbAQ
# 223015   439UPa3tzzHxXoK87DI37A  ZBCmWKnqjUNarl70phoM6g
# ...                         ...                     ...
# 3277206  kYSkLpJckW9LKbWPsp8a6A  3hjFgJ57yvTGSZKN363LDQ
# 4521832  ai9tYHZxr4OEck1tkJ5X2Q  IYxFMcTI-bPmAG3ptQI5TA
# 663565   S2DpQbPDZ7mSObYG_c-d1w  OpKvStdqSWZqDXHdCiuZZA
# 3629507  csxzEmM6ytsnRh6l-0mBeg  sLNHFRk3Bssc8VuMvehIBg
# 3955822  UniXnVymUjCW9mKoN_JKQA  _qpZgV3vrYUYvBD5MDW6oQ
#
#                     business_id  stars  useful  funny  cool  \
# 6022763  Kg0gJ_3lGToLjuXrLY12Ng      2       0      0     0
# 4956041  QK9s-Chx69_U-M2gsPb3Gw      2       0      0     0
# 6032674  uHkO-VYglIeZafsny21O3Q      2       0      0     0
# ...

# %%
shuffled_Df.to_csv(path_or_buf="Shuffled_CSV.csv", index=False)
